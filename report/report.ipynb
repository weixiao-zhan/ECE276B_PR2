# %% [markdown]
# Here is the updated table without the "RRT First Find Result" and "Astar Runtime (s)" columns:
#
# | Map         | Astar Result        | PRM Result         | RRT Result         | RRTstar First Find Result    | RRTstar Result   |
# |-------------|---------------------|--------------------|--------------------|-----------------------------|------------------|
# | single_cube | 8.259574080173985   | 8.042867838418864  | 15.467175364935965 | 10.13824728984762            | 8.076796652543138|
# | maze        | 75.61937205481868   | 76.16699617325877  | 111.8629328533957  | N/A                          | inf              |
# | window      | 25.156096188923108  | 23.995759170225302 | 29.806141363254003 | 25.753350943191016           | 24.266853172694336|
# | tower       | 29.13074909764859   | 28.443081268124203 | 46.27710831727874  | 34.96240911398771            | 28.896640526766294|
# | flappy_bird | 26.04751801064716   | 25.64781137548039  | 37.60486865840876  | 32.12711679360361            | 25.792809148632923|
# | room        | 11.471067811865472  | 10.905652212557984 | 13.73187776888044  | 11.11288668797752            | 11.903614140180555|
# | monza       | 76.40530428401738   | 74.6420581052761   | inf                | N/A                          | inf              |
#
# This table now focuses on the path costs for each algorithm and map.
